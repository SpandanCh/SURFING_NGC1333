# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy.io import fits
from aplpy import FITSFigure
from astropy.io.fits import PrimaryHDU
import astropy.units as u

import matplotlib as mpl
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['ytick.direction'] = 'in'

# %% [markdown]
# ### read in master arrays

# %%
tp_master_C18O_3sigma = fits.getdata('para_maps_funstools/tp_master_C18O_3sigma.fits')
vel_master_C18O_3sigma = fits.getdata('para_maps_funstools/vel_master_C18O_3sigma.fits')
sig_master_C18O_3sigma = fits.getdata('para_maps_funstools/sig_master_C18O_3sigma.fits')
mom0_master_C18O_3sigma = fits.getdata('para_maps_funstools/mom0_master_C18O_3sigma.fits')

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15,10), sharex=True, sharey=True, 
                       gridspec_kw={'hspace': 0.04, 'wspace' : -0.68, 'left':0.05, 'right':0.98, 'top':0.97, 
                                    'bottom':0.15})

k = 0

for i in range(2):
    for j in range(3):
        ax[i,j].imshow(vel_master_C18O_3sigma[k], origin='lower', vmin=4, vmax=10, cmap='RdYlBu_r')
        
        k += 1

# %% [markdown]
# #### sort by integrated intensity

# %%
dummy_arr_1 = np.zeros((4,)+ tp_master_C18O_3sigma.shape[1:]) * np.nan
dummy_arr_2 = np.zeros((4,)+ tp_master_C18O_3sigma.shape[1:]) * np.nan
dummy_arr_3 = np.zeros((4,)+ tp_master_C18O_3sigma.shape[1:]) * np.nan
dummy_arr_4 = np.zeros((4,)+ tp_master_C18O_3sigma.shape[1:]) * np.nan
dummy_arr_5 = np.zeros((4,)+ tp_master_C18O_3sigma.shape[1:]) * np.nan
dummy_arr_6 = np.zeros((4,)+ tp_master_C18O_3sigma.shape[1:]) * np.nan

# %%
rem_arr = np.zeros(tp_master_C18O_3sigma.shape) * np.nan

# %%
for i in range(tp_master_C18O_3sigma.shape[1]):
    for j in range(tp_master_C18O_3sigma.shape[2]):
#         sort_para_all = tp_master_C18O_3sigma[:, i, j].copy()
#         sort_para_all = mom0_master_C18O_3sigma[:, i, j].copy()
        
        if np.isfinite(np.nanmax(sort_para_all)):
            
            loc_1 = np.where(sort_para_all == np.nanmax(sort_para_all))[0][0]
            dummy_arr_1[0, i, j] = tp_master_C18O_3sigma[loc_1, i, j]
            dummy_arr_1[1, i, j] = vel_master_C18O_3sigma[loc_1, i, j]
            dummy_arr_1[2, i, j] = sig_master_C18O_3sigma[loc_1, i, j]
            dummy_arr_1[3, i, j] = mom0_master_C18O_3sigma[loc_1, i, j]
            sort_para_all[loc_1] = np.nan
            
            if np.isfinite(np.nanmax(sort_para_all)):
                loc_2 = np.where(sort_para_all == np.nanmax(sort_para_all))[0][0]
                dummy_arr_2[0, i, j] = tp_master_C18O_3sigma[loc_2, i, j]
                dummy_arr_2[1, i, j] = vel_master_C18O_3sigma[loc_2, i, j]
                dummy_arr_2[2, i, j] = sig_master_C18O_3sigma[loc_2, i, j]
                dummy_arr_2[3, i, j] = mom0_master_C18O_3sigma[loc_2, i, j]
                sort_para_all[loc_2] = np.nan
                
                if np.isfinite(np.nanmax(sort_para_all)):
                    loc_3 = np.where(sort_para_all == np.nanmax(sort_para_all))[0][0]
                    dummy_arr_3[0, i, j] = tp_master_C18O_3sigma[loc_3, i, j]
                    dummy_arr_3[1, i, j] = vel_master_C18O_3sigma[loc_3, i, j]
                    dummy_arr_3[2, i, j] = sig_master_C18O_3sigma[loc_3, i, j]
                    dummy_arr_3[3, i, j] = mom0_master_C18O_3sigma[loc_3, i, j]
                    sort_para_all[loc_3] = np.nan
                    
                    if np.isfinite(np.nanmax(sort_para_all)):
                        loc_4 = np.where(sort_para_all == np.nanmax(sort_para_all))[0][0]
                        dummy_arr_4[0, i, j] = tp_master_C18O_3sigma[loc_4, i, j]
                        dummy_arr_4[1, i, j] = vel_master_C18O_3sigma[loc_4, i, j]
                        dummy_arr_4[2, i, j] = sig_master_C18O_3sigma[loc_4, i, j]
                        dummy_arr_4[3, i, j] = mom0_master_C18O_3sigma[loc_4, i, j]
                        sort_para_all[loc_4] = np.nan
                        
                        if np.isfinite(np.nanmax(sort_para_all)):
                            loc_5 = np.where(sort_para_all == np.nanmax(sort_para_all))[0][0]
                            dummy_arr_5[0, i, j] = tp_master_C18O_3sigma[loc_5, i, j]
                            dummy_arr_5[1, i, j] = vel_master_C18O_3sigma[loc_5, i, j]
                            dummy_arr_5[2, i, j] = sig_master_C18O_3sigma[loc_5, i, j]
                            dummy_arr_5[3, i, j] = mom0_master_C18O_3sigma[loc_5, i, j]
                            sort_para_all[loc_5] = np.nan

                            if np.isfinite(np.nanmax(sort_para_all)):
                                loc_6 = np.where(sort_para_all == np.nanmax(sort_para_all))[0][0]
                                dummy_arr_6[0, i, j] = tp_master_C18O_3sigma[loc_6, i, j]
                                dummy_arr_6[1, i, j] = vel_master_C18O_3sigma[loc_6, i, j]
                                dummy_arr_6[2, i, j] = sig_master_C18O_3sigma[loc_6, i, j]
                                dummy_arr_6[3, i, j] = mom0_master_C18O_3sigma[loc_6, i, j]
                                sort_para_all[loc_6] = np.nan
                                

        rem_arr[:, i, j] = sort_para_all
# Out:
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2482120595.py:7: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmax(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2482120595.py:16: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmax(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2482120595.py:24: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmax(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2482120595.py:32: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmax(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2482120595.py:40: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmax(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2482120595.py:48: RuntimeWarning: All-NaN slice encountered
# ...

# %%
for i in range(tp_master_C18O_3sigma.shape[1]):
    for j in range(tp_master_C18O_3sigma.shape[2]):
        sort_para_all = sig_master_C18O_3sigma[:, i, j].copy()
        
        if np.isfinite(np.nanmin(sort_para_all)):
            
            loc_1 = np.where(sort_para_all == np.nanmin(sort_para_all))[0][0]
            dummy_arr_1[0, i, j] = tp_master_C18O_3sigma[loc_1, i, j]
            dummy_arr_1[1, i, j] = vel_master_C18O_3sigma[loc_1, i, j]
            dummy_arr_1[2, i, j] = sig_master_C18O_3sigma[loc_1, i, j]
            dummy_arr_1[3, i, j] = mom0_master_C18O_3sigma[loc_1, i, j]
            sort_para_all[loc_1] = np.nan
            
            if np.isfinite(np.nanmin(sort_para_all)):
                loc_2 = np.where(sort_para_all == np.nanmin(sort_para_all))[0][0]
                dummy_arr_2[0, i, j] = tp_master_C18O_3sigma[loc_2, i, j]
                dummy_arr_2[1, i, j] = vel_master_C18O_3sigma[loc_2, i, j]
                dummy_arr_2[2, i, j] = sig_master_C18O_3sigma[loc_2, i, j]
                dummy_arr_2[3, i, j] = mom0_master_C18O_3sigma[loc_2, i, j]
                sort_para_all[loc_2] = np.nan
                
                if np.isfinite(np.nanmin(sort_para_all)):
                    loc_3 = np.where(sort_para_all == np.nanmin(sort_para_all))[0][0]
                    dummy_arr_3[0, i, j] = tp_master_C18O_3sigma[loc_3, i, j]
                    dummy_arr_3[1, i, j] = vel_master_C18O_3sigma[loc_3, i, j]
                    dummy_arr_3[2, i, j] = sig_master_C18O_3sigma[loc_3, i, j]
                    dummy_arr_3[3, i, j] = mom0_master_C18O_3sigma[loc_3, i, j]
                    sort_para_all[loc_3] = np.nan
                    
                    if np.isfinite(np.nanmin(sort_para_all)):
                        loc_4 = np.where(sort_para_all == np.nanmin(sort_para_all))[0][0]
                        dummy_arr_4[0, i, j] = tp_master_C18O_3sigma[loc_4, i, j]
                        dummy_arr_4[1, i, j] = vel_master_C18O_3sigma[loc_4, i, j]
                        dummy_arr_4[2, i, j] = sig_master_C18O_3sigma[loc_4, i, j]
                        dummy_arr_4[3, i, j] = mom0_master_C18O_3sigma[loc_4, i, j]
                        sort_para_all[loc_4] = np.nan
                        
                        if np.isfinite(np.nanmin(sort_para_all)):
                            loc_5 = np.where(sort_para_all == np.nanmin(sort_para_all))[0][0]
                            dummy_arr_5[0, i, j] = tp_master_C18O_3sigma[loc_5, i, j]
                            dummy_arr_5[1, i, j] = vel_master_C18O_3sigma[loc_5, i, j]
                            dummy_arr_5[2, i, j] = sig_master_C18O_3sigma[loc_5, i, j]
                            dummy_arr_5[3, i, j] = mom0_master_C18O_3sigma[loc_5, i, j]
                            sort_para_all[loc_5] = np.nan

                            if np.isfinite(np.nanmin(sort_para_all)):
                                loc_6 = np.where(sort_para_all == np.nanmin(sort_para_all))[0][0]
                                dummy_arr_6[0, i, j] = tp_master_C18O_3sigma[loc_6, i, j]
                                dummy_arr_6[1, i, j] = vel_master_C18O_3sigma[loc_6, i, j]
                                dummy_arr_6[2, i, j] = sig_master_C18O_3sigma[loc_6, i, j]
                                dummy_arr_6[3, i, j] = mom0_master_C18O_3sigma[loc_6, i, j]
                                sort_para_all[loc_6] = np.nan
                                

        rem_arr[:, i, j] = sort_para_all
# Out:
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2229383770.py:5: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmin(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2229383770.py:14: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmin(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2229383770.py:22: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmin(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2229383770.py:30: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmin(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2229383770.py:38: RuntimeWarning: All-NaN slice encountered
#   if np.isfinite(np.nanmin(sort_para_all)):
# /var/folders/sk/jfjx4bmj537bjltqh3y2ldph0000gn/T/ipykernel_15684/2229383770.py:46: RuntimeWarning: All-NaN slice encountered
# ...

# %%
dummy_arrays_list = [dummy_arr_1, dummy_arr_2, dummy_arr_3, dummy_arr_4, dummy_arr_5, dummy_arr_6]

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15,10), sharex=True, sharey=True, 
                       gridspec_kw={'hspace': 0.04, 'wspace' : -0.68, 'left':0.05, 'right':0.98, 'top':0.97, 
                                    'bottom':0.15})

k = 0

for i in range(2):
    for j in range(3):
        ax[i,j].imshow(dummy_arrays_list[k][1], origin='lower', vmin=6, vmax=9, cmap='RdYlBu_r')
        
        k += 1

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15,10), sharex=True, sharey=True, 
                       gridspec_kw={'hspace': 0.04, 'wspace' : -0.68, 'left':0.05, 'right':0.98, 'top':0.97, 
                                    'bottom':0.15})

k = 0

for i in range(2):
    for j in range(3):
        ax[i,j].imshow(dummy_arrays_list[k][2], origin='lower', vmin=0, vmax=1, cmap='inferno')
        
        k += 1

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15,10), sharex=True, sharey=True, 
                       gridspec_kw={'hspace': 0.04, 'wspace' : -0.68, 'left':0.05, 'right':0.98, 'top':0.97, 
                                    'bottom':0.15})

k = 0

for i in range(2):
    for j in range(3):
        ax[i,j].imshow(dummy_arrays_list[k][1], origin='lower', vmin=3, vmax=12, cmap='RdYlBu_r')
        
        k += 1

# %%
# Out:
# '/Users/spandan/Desktop/SURFING_data/NGC1333'

# %%
spec1_13CO = np.loadtxt('example_spectra/spectra_1_13CO.tsv')
spec2_13CO = np.loadtxt('example_spectra/spectra_2_13CO.tsv')
spec3_13CO = np.loadtxt('example_spectra/spectra_3_13CO.tsv')
spec4_13CO = np.loadtxt('example_spectra/spectra_4_13CO.tsv')

# %%
spec1_C18O = np.loadtxt('example_spectra/spectra_1_C18O.tsv')
spec2_C18O = np.loadtxt('example_spectra/spectra_2_C18O.tsv')
spec3_C18O = np.loadtxt('example_spectra/spectra_3_C18O.tsv')
spec4_C18O = np.loadtxt('example_spectra/spectra_4_C18O.tsv')

# %%
plt.plot(spec1_13CO[:, 0], spec1_13CO[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/ek_13CO', dpi=100)

# %%
plt.plot(spec2_13CO[:, 0], spec2_13CO[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/dui_13CO', dpi=100)

# %%
plt.plot(spec3_13CO[:, 0], spec3_13CO[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/tini_13CO', dpi=100)

# %%
plt.plot(spec4_13CO[:, 0], spec4_13CO[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/sari_13CO', dpi=100)

# %%
plt.plot(spec1_C18O[:, 0], spec1_C18O[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/ek_C18O', dpi=100)

# %%
plt.plot(spec2_C18O[:, 0], spec2_C18O[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/dui_C18O', dpi=100)

# %%
plt.plot(spec3_C18O[:, 0], spec3_C18O[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/tini_C18O', dpi=100)

# %%
plt.plot(spec4_C18O[:, 0], spec4_C18O[:, 1], drawstyle='steps-mid')

# plt.xlim(-15, 20)

plt.xlabel(r'v$_{LSR}$ (km$\,s^{-1}$)')
plt.ylabel(r'$T_a$ (K)')

plt.savefig('example_spectra/sari_C18O', dpi=100)
